# %% [markdown]
# # A Brief Look at the Output File Contents
# Please run this notebook after running main.py

# %%
import pandas as pd
df_market = pd.read_csv("output/market_data.csv")

# %% [markdown]
# # Market Price Dataframe
# - Volume is total volume (both bid and ask)

# %%
df_market.head()
# Out:
#              bist_time    ask    bid  volume
# 0  1663743600232709629  19.93  19.92   57902
# 1  1663743600575170650  19.93  19.92   78478
# 2  1663743600578194994  19.93  19.92   78478
# 3  1663743600652958895  19.93  19.92   77814
# 4  1663743600704343042  19.93  19.92   77752

# %%
df_market.tail()
# Out:
#                 bist_time    ask    bid   volume
# 1090  1663743922915526631  19.98  19.92  1902280
# 1091  1663743922915920316  19.93  19.92  1912671
# 1092  1663743922915996898  19.93  19.92  1909528
# 1093  1663743922945478027  19.93  19.92  1908522
# 1094  1663743924673960552  19.93  19.92  1909532

# %%
df_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bist_time  1095 non-null   int64
#  1   ask        1095 non-null   float64
#  2   bid        1095 non-null   float64
#  3   volume     1095 non-null   int64
# dtypes: float64(2), int64(2)
# memory usage: 34.3 KB

# %% [markdown]
# ## Bid - Ask Prices Graph

# %%
# plot ask and bid
df_market.plot(x='bist_time', y=['ask', 'bid'])
# Out:
# <AxesSubplot:xlabel='bist_time'>

# %% [markdown]
# # Total Order Book Volume

# %%
# plot volume
df_market.plot(x='bist_time', y=['volume'])
# Out:
# <AxesSubplot:xlabel='bist_time'>

# %%
df_trades = pd.read_csv("output/trades.csv")

# %% [markdown]
# # Trades Dataframe
# - From "output/trades.csv"

# %%
df_trades.drop(df_trades.columns[-1], axis=1, inplace=True) # drop the last column of NaN values
df_trades.head()
# Out:
#              bist_time  price  qty                                 bid_key  \
# 0  1663743600232709629  19.93   14  76219690894289639221663743600145842219
# 1  1663743600575170650  19.93   21  76219690894289639221663743600145842219
# 2  1663743600578194994  19.93    1  76219690894289639221663743600145842219
# 3  1663743600652958895  19.93  664  76219690894289639221663743600145842219
# 4  1663743600652958895  19.93  838  76219690894289947491663743600145842219
#
#                                   ask_key
# 0  76219690894294590831663743600232709629
# 1  76219690894294590831663743600575170650
# 2  76219690894294590831663743600578194994
# 3  76219690894294590831663743600652958895
# 4  76219690894294590831663743600652958895

# %%
df_trades.tail()
# Out:
#                 bist_time  price   qty  \
# 1941  1663743922915996898  19.93  2500
# 1942  1663743922915996898  19.93   552
# 1943  1663743922945478027  19.92  1058
# 1944  1663743922945478027  19.92  1442
# 1945  1663743924673960552  19.92   495
#
#                                      bid_key  \
# 1941  76219690894308150681663743922915526631
# 1942  76219690894316649451663743922915526631
# 1943  76219690894316698781663743922945478027
# 1944  76219690894316698781663743922945478027
# 1945  76219690894316822301663743924673960552
#
#                                      ask_key
# 1941  76219690894316696491663743922915996898
# 1942  76219690894316696491663743922915996898
# 1943  76219690894309705941663743819066118276
# 1944  76219690894313430321663743875981469363
# 1945  76219690894313430321663743875981469363

# %%
df_trades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1946 entries, 0 to 1945
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bist_time  1946 non-null   int64
#  1   price      1946 non-null   float64
#  2   qty        1946 non-null   int64
#  3   bid_key    1946 non-null   object
#  4   ask_key    1946 non-null   object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 76.1+ KB

# %% [markdown]
# # LOB Dataframe
# - From "output/LOB.csv"
# - Lists top 3 bid and asks prices, their volumes, along with the bist_time of incoming order every time a  trade happens.

# %%
df_lob = pd.read_csv("output/LOB.csv")

# %%
df_lob.head(20)
# Out:
#               bist_time  ask_price1  ask_vol1  ask_price2  ask_vol2  \
# 0   1663743600232709629       19.93     52586       19.94      5300
# 1   1663743600575170650       19.93     52565       19.94     25075
# 2   1663743600578194994       19.93     52564       19.94     25075
# 3   1663743600652958895       19.93     51062       19.94     25075
# 4   1663743600704343042       19.93     50100       19.94     25075
# 5   1663743600704343042       19.93     47600       19.94     25075
# 6   1663743601130848327       19.93     47210       19.94     25075
# 7   1663743601130848327       19.93     47180       19.94     25075
# 8   1663743601130848327       19.93     46180       19.94     25075
# 9   1663743601130848327       19.93     46150       19.94     25075
# 10  1663743601130848327       19.93     46100       19.94     25075
# 11  1663743601231889855       19.93     45900       19.94     25075
# 12  1663743601232338028       19.93     43600       19.94     25075
# ...

# %%
df_lob.tail()
# Out:
#                 bist_time  ask_price1  ask_vol1  ask_price2  ask_vol2  \
# 1090  1663743922915526631       19.98     19102       20.00     23665
# 1091  1663743922915920316       19.93      6150       19.94      1005
# 1092  1663743922915996898       19.93      2455       19.94      1005
# 1093  1663743922945478027       19.93      2977       19.94      1005
# 1094  1663743924673960552       19.93      2977       19.94      1005
#
#      ask_price3 ask_vol3  bid_price1  bid_vol1 bid_price2 bid_vol2 bid_price3  \
# 1090      20.02     3091       19.92     71243      19.91    92884       19.9
# 1091      19.95     2794       19.92     71243      19.91    92884       19.9
# 1092      19.95     2794       19.92     71243      19.91    92884       19.9
# 1093      19.95     2794       19.92     68743      19.91    92884       19.9
# 1094      19.95     2794       19.92     68248      19.91    93894       19.9
#
#      bid_vol3
# 1090   310996
# 1091   310996
# 1092   310996
# ...

# %%
df_lob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bist_time   1095 non-null   int64
#  1   ask_price1  1095 non-null   float64
#  2   ask_vol1    1095 non-null   int64
#  3   ask_price2  1095 non-null   float64
#  4   ask_vol2    1095 non-null   int64
#  5   ask_price3  1095 non-null   object
#  6   ask_vol3    1095 non-null   object
#  7   bid_price1  1095 non-null   float64
#  8   bid_vol1    1095 non-null   int64
#  9   bid_price2  1095 non-null   object
#  10  bid_vol2    1095 non-null   object
#  11  bid_price3  1095 non-null   object
#  12  bid_vol3    1095 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 111.3+ KB
