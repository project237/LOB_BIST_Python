# %% [markdown]
# # A Brief Look at the Output File Contents
# Please run this notebook after running main.py

# %%
import pandas as pd
df_market = pd.read_csv("output/market_data.csv")

# %% [markdown]
# # Market Price Dataframe
# - Volume is total volume (both bid and ask)

# %%
df_market.head()
# Out:
#              bist_time    ask    bid  volume
# 0  1663743600232709629  19.93  19.92   57902
# 1  1663743600575170650  19.93  19.92   78478
# 2  1663743600578194994  19.93  19.92   78478
# 3  1663743600652958895  19.93  19.92   77814
# 4  1663743600704343042  19.93  19.92   77752

# %%
df_market.tail()
# Out:
#                  bist_time    ask    bid    volume
# 56842  1663772941781462619  19.56  19.49  51195876
# 56843  1663772942009365880  19.56  19.49  51195876
# 56844  1663772947418054939  19.56  19.49  51242340
# 56845  1663772947443060471  19.56  19.49  51242340
# 56846  1663772947719922796  19.56  19.49  51242340

# %%
df_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56847 entries, 0 to 56846
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bist_time  56847 non-null  int64
#  1   ask        56847 non-null  float64
#  2   bid        56847 non-null  float64
#  3   volume     56847 non-null  int64
# dtypes: float64(2), int64(2)
# memory usage: 1.7 MB

# %% [markdown]
# ## Bid - Ask Prices Graph

# %%
# plot ask and bid
df_market.plot(x='bist_time', y=['ask', 'bid'])
# Out:
# <AxesSubplot:xlabel='bist_time'>

# %% [markdown]
# # Total Order Book Volume

# %%
# plot volume
df_market.plot(x='bist_time', y=['volume'])
# Out:
# <AxesSubplot:xlabel='bist_time'>

# %%
df_trades = pd.read_csv("output/trades.csv")

# %% [markdown]
# # Trades Dataframe
# - From "output/trades.csv"

# %%
df_trades.drop(df_trades.columns[-1], axis=1, inplace=True) # drop the last column of NaN values
df_trades.head()
# Out:
#              bist_time  price  qty               bid_id               ask_id
# 0  1663743600232709629  19.93   14  7621969089428963922  7621969089429459083
# 1  1663743600575170650  19.93   21  7621969089428963922  7621969089429459083
# 2  1663743600578194994  19.93    1  7621969089428963922  7621969089429459083
# 3  1663743600652958895  19.93  664  7621969089428963922  7621969089429459083
# 4  1663743600652958895  19.93  838  7621969089428994749  7621969089429459083

# %%
df_trades.tail()
# Out:
#                  bist_time  price   qty               bid_id  \
# 98973  1663772947418054939  19.49   500  7621969089510718378
# 98974  1663772947418054939  19.49   177  7621969089510718378
# 98975  1663772947418054939  19.49   303  7621969089510718378
# 98976  1663772947443060471  19.49  2700  7621969089510718378
# 98977  1663772947719922796  19.49   639  7621969089510718378
#
#                     ask_id
# 98973  7621969089494035867
# 98974  7621969089493030490
# 98975  7621969089482088766
# 98976  7621969089482088766
# 98977  7621969089482088766

# %%
df_trades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98978 entries, 0 to 98977
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bist_time  98978 non-null  int64
#  1   price      98978 non-null  float64
#  2   qty        98978 non-null  int64
#  3   bid_id     98978 non-null  int64
#  4   ask_id     98978 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 3.8 MB
